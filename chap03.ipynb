# %%
import pandas as pd
import numpy as np

# %precision 3
df = pd.read_csv('./data/ch2_scores_em.csv',index_col = 'student number')

# %%
en_scores = np.array(df['english'])[:10]
ma_scores = np.array(df['mathematics'])[:10]

scores_df = pd.DataFrame({'english':en_scores,
                         'mathematics':ma_scores},
                         index=pd.Index(['A','B','C','D','E',
                                         'F','G','H','I','J'],
                                        name = 'student'))
scores_df
# Out:
#          english  mathematics
# student
# A             42           65
# B             69           80
# C             56           63
# D             41           63
# E             57           76
# F             48           60
# G             65           81
# H             49           66
# I             65           78
# J             58           82

# %%
summary_df = scores_df.copy()
summary_df['english_deviation'] =\
    summary_df['english'] - summary_df['english'].mean()
summary_df['mathematics_deviation'] =\
    summary_df['mathematics'] - summary_df['mathematics'].mean()

summary_df['product of deviations'] =\
    summary_df['english_deviation'] * summary_df['mathematics_deviation']
summary_df
# Out:
#          english  mathematics  english_deviation  mathematics_deviation  \
# student
# A             42           65              -13.0                   -6.4
# B             69           80               14.0                    8.6
# C             56           63                1.0                   -8.4
# D             41           63              -14.0                   -8.4
# E             57           76                2.0                    4.6
# F             48           60               -7.0                  -11.4
# G             65           81               10.0                    9.6
# H             49           66               -6.0                   -5.4
# I             65           78               10.0                    6.6
# J             58           82                3.0                   10.6
#
#          product of deviations
# student
# A                         83.2
# B                        120.4
# C                         -8.4
# ...

# %%
summary_df['product of deviations'].mean()
# Out:
# 62.800

# %%
#영어와 수학의 공분산 행렬 만들기

cov_mat = np.cov(en_scores,ma_scores, ddof=0)
cov_mat
# Out:
# array([[86.  , 62.8 ],
#        [62.8 , 68.44]])

# %%
cov_mat[0,0], cov_mat[1,1]   #영어와 수학의 공분산 각각 구해진 값
# Out:
# (86.000, 68.440)

# %%
np.var(en_scores,ddof=0), np.var(ma_scores,ddof=0)
# Out:
# (86.000, 68.440)

# %%
cov_mat[0,1],cov_mat[1,0] #영어 + 수학 공분산 각각 구해진 값
# Out:
# (62.800, 62.800)

# %%
# 상관계수
# 공분산을 표준편차로 나누어준다

np.cov(en_scores,ma_scores,ddof=0)[0,1] /\
(np.std(en_scores)*np.std(ma_scores))
# Out:
# 0.819

# %%
np.corrcoef(en_scores,ma_scores)
# Out:
# array([[1.   , 0.819],
#        [0.819, 1.   ]])

# %%
# Dataframe의 상관계수 코드

scores_df.corr()
# Out:
#               english  mathematics
# english      1.000000     0.818569
# mathematics  0.818569     1.000000

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
english_scores = np.array(df['english'])
math_scores = np.array(df['mathematics'])

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111)

#산점도
ax.scatter(english_scores,math_scores)
ax.set_xlabel('english')
ax.set_ylabel('mathematics')

plt.show()

# %%
# 회귀직선 만들기 (y = ax+b)

#polyfit 함수는 첫번째 인수는 a이고 두번째 인수는 절편, 1은 1차다항식)
poly_fit = np.polyfit(english_scores,math_scores,1)
# y = ax+b 만들어줌.
poly_1d = np.poly1d(poly_fit)

#xs는 영어 좌표 구간, ys는 영어좌표 구간에 따른 수학 좌표
xs = np.linspace(english_scores.min(),english_scores.max())
ys = poly_1d(xs)

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.set_xlabel('english')
ax.set_ylabel('mathematics')
ax.scatter(english_scores,math_scores,label='score')
ax.plot(xs,ys,color='gray',
        label=f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x') #라벨에 함수 기울기와 절편 표시
ax.legend(loc='upper left')

plt.show()

# %%
# 히트맵

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)

c = ax.hist2d(english_scores,math_scores,
              bins=[9,8], range=[(35,80),(55,95)])
ax.set_xlabel('english')
ax.set_ylabel('mathematics')
ax.set_xticks(c[1])
ax.set_yticks(c[2])

fig.colorbar(c[3],ax=ax)
plt.show()

# %%
anscombe_data = np.load('./data/ch3_anscombe.npy')
print(anscombe_data.shape)
anscombe_data[0]
# Out:
# (4, 11, 2)
# array([[10.  ,  8.04],
#        [ 8.  ,  6.95],
#        [13.  ,  7.58],
#        [ 9.  ,  8.81],
#        [11.  ,  8.33],
#        [14.  ,  9.96],
#        [ 6.  ,  7.24],
#        [ 4.  ,  4.26],
#        [12.  , 10.84],
#        [ 7.  ,  4.82],
#        [ 5.  ,  5.68]])

# %%
stats_df = pd.DataFrame(index=['X_mean','X_variance','Y_mean','Y_variance',
                               'X&Y_correlation','X&Y_regression_line'])
for i, data in enumerate(anscombe_data):
    dataX = data[:,0]
    dataY = data[:,1]
    poly_fit = np.polyfit(dataX,dataY,1)
    stats_df[f'data{i+1}'] = \
        [f'{np.mean(dataX):.2f}',
         f'{np.var(dataX): .2f}',
         f'{np.mean(dataY): .2f}',
         f'{np.var(dataY): .2f}',
         f'{np.corrcoef(dataX, dataY)[0,1]:.2f}',
         f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x']

stats_df
# Out:
#                           data1       data2       data3       data4
# X_mean                     9.00        9.00        9.00        9.00
# X_variance                10.00       10.00       10.00       10.00
# Y_mean                     7.50        7.50        7.50        7.50
# Y_variance                 3.75        3.75        3.75        3.75
# X&Y_correlation            0.82        0.82        0.82        0.82
# X&Y_regression_line  3.00+0.50x  3.00+0.50x  3.00+0.50x  3.00+0.50x

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,10),
                         sharex=True, sharey=True)

xs = np.linspace(0,30,100)
for i, data in enumerate(anscombe_data):
    poly_fit = np.polyfit(data[:,0],data[:,1],1)
    poly_1d = np.poly1d(poly_fit)
    ys = poly_1d(xs)

    ax = axes[i//2,i%2]
    ax.set_xlim([4,20])
    ax.set_ylim([3,13])

    ax.set_title(f'data{i+1}')
    ax.scatter(data[:,0],data[:,1])
    ax.plot(xs,ys,color='gray')

plt.tight_layout()
plt.show()
